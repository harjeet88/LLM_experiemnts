# %% [markdown]
# <a href="https://colab.research.google.com/github/harjeet88/LLM_experiemnts/blob/main/deepseek/deepseek_failed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade transformers

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
model_id = "deepseek-ai/deepseek-coder-1.3b-instruct"
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.87k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.37M [00:00<?, ?B/s]

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",  # Works on CPU/GPU
    torch_dtype="auto"   # Auto-select precision
)
# Out:
# config.json:   0%|          | 0.00/631 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.69G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]

# %%
prompt = "which model is provided by deepseek for coding"
inputs = tokenizer(prompt, return_tensors="pt")
outputs = model.generate(**inputs, max_new_tokens=200)
# Out:
# Setting `pad_token_id` to `eos_token_id`:32021 for open-end generation.

# %%
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# which model is provided by deepseek for coding
#
#
# #!/bin/bash
#
# # This script is used to install the required software for the deepseek project.
#
# # Update the system
# sudo apt-get update
#
# # Install Python
# sudo apt-get install python3-pip python3-dev python3-venv
#
# # Install pipenv
# pip3 install pipenv
#
# # Install virtualenv
# pip3 install virtualenv
#
# # Install Node.js and npm
# sudo apt-get install -y nodejs npm
#
# # Install Yarn
# npm install --global yarn
#
# # Install Docker
# sudo apt-get install -y docker.io
#
# # Install Docker Compose
# sudo curl -L "https://github.com/docker/compose/releases/download/1.29.2/docker-compose-$(uname -s)-$(uname -m)" -o /usr/local

# %%
file_content = """torch==2.0.1
transformers==4.38.2
xformers>=0.0.21
timm>=0.9.16
accelerate
sentencepiece
attrdict
einops

# for gradio demo
gradio==3.48.0
gradio-client==0.6.1
mdtex2html==1.3.0
pypinyin==0.50.0
tiktoken==0.5.2
tqdm==4.64.0
colorama==0.4.5
Pygments==2.12.0
markdown==3.4.1
SentencePiece==0.1.96
"""

with open("requirements.txt", "w") as f:
  f.write(file_content)

# %%
# !pip install -e .
# Out:
# Obtaining file:///content
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 377, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/resolution/resolvelib/resolver.py", line 76, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import torch
from transformers import AutoModelForCausalLM

from deepseek_vl.models import DeepseekVLV2Processor, DeepseekVLV2ForCausalLM
from deepseek_vl.utils.io import load_pil_images
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-10-1204123494.py in <cell line: 0>()
#       2 from transformers import AutoModelForCausalLM
#       3
# ----> 4 from deepseek_vl.models import DeepseekVLV2Processor, DeepseekVLV2ForCausalLM
#       5 from deepseek_vl.utils.io import load_pil_images
#
# ModuleNotFoundError: No module named 'deepseek_vl'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
model_lite="deepseek-ai/deepseek-vl2-small"
tokenizer = AutoTokenizer.from_pretrained(model_lite)
# Out:
# tokenizer_config.json:   0%|          | 0.00/3.47k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/799 [00:00<?, ?B/s]

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_lite,
    device_map="auto",  # Works on CPU/GPU
    torch_dtype="auto"   # Auto-select precision
)
# Out:
# config.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1169             try:
# -> 1170                 config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1171             except KeyError:
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/configuration_auto.py in __getitem__(self, key)
#     871         if key not in self._mapping:
# --> 872             raise KeyError(key)
#     873         value = self._mapping[key]
#
# KeyError: 'deepseek_vl_v2'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...
