# %% [markdown]
# <a href="https://colab.research.google.com/github/harjeet88/LLM_experiemnts/blob/main/01_vibecode/01_opencode_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#one time
#!mkdir /content/drive/MyDrive/dev/llm/opencode/

# %%
# !curl -fsSL https://opencode.ai/install | bash
# Out:
# Installing opencode version: 1.17.9
# ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■ 100%
# Successfully added opencode to $PATH in /root/.bashrc
#
#                                  ▄
# █▀▀█ █▀▀█ █▀▀█ █▀▀▄ █▀▀▀ █▀▀█ █▀▀█ █▀▀█
# █░░█ █░░█ █▀▀▀ █░░█ █░░░ █░░█ █░░█ █▀▀▀
# ▀▀▀▀ █▀▀▀ ▀▀▀▀ ▀  ▀ ▀▀▀▀ ▀▀▀▀ ▀▀▀▀ ▀▀▀▀
#
#
# OpenCode includes free models, to start:
#
# cd <project>  # Open directory
# opencode      # Run command
#
# For more information visit https://opencode.ai/docs

# %%
import os
os.environ['PATH'] += ':/root/.opencode/bin'

# %%
# !source ~/.bashrc

# %%
# move to directory /content/drive/MyDrive/dev/llm/opencode/ in terminal
#and run opencode

# %%
import IPython

html_file="/content/dev/open_code/kanban/index.html"
# Read the HTML file you created
with open(html_file, 'r') as file:
    html_content = file.read()

# Render it inside the notebook
IPython.display.HTML(html_content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2093/3460382582.py in <cell line: 0>()
#       3 html_file="/content/dev/open_code/kanban/index.html"
#       4 # Read the HTML file you created
# ----> 5 with open(html_file, 'r') as file:
#       6     html_content = file.read()
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/dev/open_code/kanban/index.html'
